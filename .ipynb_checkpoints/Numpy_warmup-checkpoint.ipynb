# %%
import numpy as np 
import matplotlib.pyplot as plt

x = np.arange(100)
y = np.linspace(0,10,100)
y_cos = np.cos(y)
y_sine = np.sin(y)
y_tan = np.tan(y)


plt.plot(x,y_cos)
plt.plot(x,y_sine)
plt.plot(x,y_tan)

# %%
import numpy as np 
sales_numbers= np.random.randint(low = 0,high=30,size=336)
unit = 300
monthly_sales= sales_numbers.reshape(12,4,7)
weekly_sales = sales_numbers.reshape(48,7)

# %%
qtys = np.sum(weekly_sales) * unit
# Out:
# 1442700

# %%
total_daily_sales_for_fiscal_year = np.sum(weekly_sales,axis=1)
qtys.astype('int')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b1d646705db1> in <module>
#       1 total_daily_sales_for_fiscal_year = np.sum(weekly_sales,axis=1)
# ----> 2 qtys.astype('int')
#
# NameError: name 'qtys' is not defined

# %%
plt.bar("mon,tue,wed,thur,fri,sat,sun".split(","),total_daily_sales_for_fiscal_year)
# Out:
# <BarContainer object of 7 artists>

# %%
total_weekly_sales_for_fiscal_year = np.sum(weekly_sales,axis=1)

# %%
enumed_vals = list(enumerate(total_weekly_sales_for_fiscal_year))
preprocessed_values = list(map(lambda x: [f"wk{x[0]}",x[1]],enumed_vals))

# %%
np_weekly_sales = np.array(preprocessed_values)
qtys = np_weekly_sales[:,1]
wks = np_weekly_sales[:,0]
wks.shape
# Out:
# (48,)

# %%
plt.bar(list(wks),(qtys))
# Out:
# <BarContainer object of 48 artists>
