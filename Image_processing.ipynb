# %%
from skimage import io
from matplotlib import pyplot as plt
#import PIL
photo = io.imread('image.jpg')

# %%
plt.imshow(photo)
plt.show()

# %%
my_crop = photo[1500:,2000:4000,] * [0,1,0]
photo[1500:,2000:4000,:] = photo[1500:,2000:4000,:]*[1,0,0]
plt.imshow(photo)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-fb1dd6e96ad2> in <module>
#       1 my_crop = photo[200:,100:200,] * [0,1,0]
# ----> 2 photo[200:,100:400,:] = photo[200:,200:400,:]*[1,0,0]
#       3 plt.imshow(photo)
#       4 plt.show()
#
# ValueError: could not broadcast input array from shape (440,200,3) into shape (440,300,3)
